# %% [markdown]
# # AI as Interpreter: Portfolio Project
#
# **Object:** [Object title / reference]
#
# **Source:** University of Glasgow Special Collections
#
# **AI Tool Used:** Microsoft Copilot
#
# **Role of AI:** Interpreter
#
# This notebook documents the use of Microsoft Copilot to generate interpretive explanations of a historical object for a general audience, followed by critical analysis of the AI’s interpretive choices, assumptions, and limitations.
# ``

# %% [markdown]
# ## 1. Object Background
#
# Describe the object here in your own words:
#
# - What the object is
# - When and where it originates
# - Who created, owned, or used it
# - Why its meaning might not be immediately clear to a modern, general audience
#
# No AI was used in writing this section.

# %% [markdown]
# ## 2. Interpretation Goal
#
# The purpose of this project is to use Microsoft Copilot as an **interpretive tool** to help explain this historical object to a **non-specialist audience**.
#
# The AI is tasked with:
# - Translating historical language into accessible modern English
# - Providing general contextual explanation
# - Offering a plausible interpretation without presenting itself as definitive
#
# The output is treated as a starting point for analysis, not as an authoritative historical account.
# ``

# %% [markdown]
# ## 3. AI Tool and Methodology
#
# **AI Tool:**
# Microsoft Copilot (generative language model)
#
# **Rationale for use:**
# Copilot was selected for its ability to generate natural-language explanations intended for general users, making it suitable for testing how AI mediates historical interpretation in public-facing contexts.
#
# **Prompt submitted to Copilot:**
