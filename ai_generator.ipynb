# %% [markdown]
# # Rewoven — Prompt Log
#
# All prompts submitted to DALL-E 2 during this project, including initial versions, DALL-E's output, and refined follow-up prompts.
#
# ---
#
# ## Generation 1 — Colonial Power Dynamics
#
# **My prompt:**
# <br><img src="media/Sample1.jpg" width="300">
# <br>Using this Tapa cloth sample, generate an image of what the cloth could have looked like before it was cut up.
#
# **DALL-E output:**
# <br><img src="media/Output1.1.png" width="300">
#
#
# **Follow-up prompt (after reviewing output):**
# <br>
#
# **Why I refined it:**
# I was expecting for Dall-E 2 to extend the cloth sample and analyse the pattern. From there, it could generate the image of what the cloths could have been used for. The results had the general concept but used the book as part of the cloth, thereby extending the book pages instead of the actual tapa cloth sample.
#
# ---
#
# ## Generation 2 — Fragmented Documentation
# [same structure]
#
# ---
#
# ## Generation 3 — Cultural Preservation
# [same structure]
