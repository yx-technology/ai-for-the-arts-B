# %% [markdown]
# # Rewoven — Prompt Log
#
# All prompts submitted to DALL-E 3 during this project, including initial prompts, DALL-E's output, and refined follow-up prompts.
#
# ---

# %% [markdown]
# ## Generation 1 — Colonial Power Dynamics
#
# **My prompt:**
# Using this Tapa cloth sample, generate an image of what the cloth could have looked like before it was cut up.

# %%
from IPython.display import Image

Image("Sample 1")

# %% [markdown]
# **DALL-E output:**
# [full text]
#
# **Follow-up prompt (after reviewing output):**
# [full text]
#
# **Why I refined it:**
# [1-2 sentences]
#
# ---
#
# ## Generation 2 — Fragmented Documentation
# [same structure]
#
# ---
#
# ## Generation 3 — Cultural Preservation
# [same structure]
